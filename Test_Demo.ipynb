# %%
from github import Github, Auth

auth = Auth.Token("access_token")
g = Github(auth=auth, lazy=True)

# %%
repo = g.get_repo("PyGithub/PyGithub") #replace w repositories of interest
repo.name
# Out:
# 'PyGithub'

# %%
print('It\'s been a minute since I coded in Python. Let\'s try a test statement.',
      '\nThese repositories should come in handy for',
      'getting me back up to speed:\n')
#i need to upload my notes / documentation repositories aaa
# Out:
# It's been a minute since I coded in Python. Let's try a test statement.
# These repositories should come in handy for getting me back up to speed:
